# %% [markdown]
# ### Importing Pandas package (eg. for imporitng train dataset in CSV format):

# %%
import pandas as pd

# %% [markdown]
# ### Importing train dataset in CSV format:

# %%
train = pd.read_csv('C:/Users/Ada/Desktop/Kaggle Group/2018-11-14/train.csv')

# %% [markdown]
# ### The first five observations of the train dataset:

# %%
train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %% [markdown]
# ### The shape of the dataset (number of rows, number of columns):

# %%
train.shape
# Out:
# (1460, 81)

# %% [markdown]
# ### Summary statistics of variables in dataset (count, mean, std, min, max, quantiles):

# %%
train.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726
# std       1.112799    30.202904     20.645407   181.066207   456.098091
# ...

# %% [markdown]
# ### Imporitng package for data visualization:

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Histogram of target variable:

# %%
plt.hist(train.SalePrice, color='blue')
# Out:
# (array([148., 723., 373., 135.,  51.,  19.,   4.,   3.,   2.,   2.]),
#  array([ 34900., 106910., 178920., 250930., 322940., 394950., 466960.,
#         538970., 610980., 682990., 755000.]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ### SalesPrice, target variable, is positively skeewed. It might be necessery to transform it (logarithm) before modeling, so it resembles normal distribution.

# %% [markdown]
# ### Five features, that are the most positively correlated with SalePrice and five that are the most negatively correlated

# %%
corr = train.corr()
print (corr['SalePrice'].sort_values(ascending=False)[1:5], '\n')
print (corr['SalePrice'].sort_values(ascending=False)[-5:])
# Out:
# OverallQual    0.790982
# GrLivArea      0.708624
# GarageCars     0.640409
# GarageArea     0.623431
# Name: SalePrice, dtype: float64
#
# YrSold          -0.028923
# OverallCond     -0.077856
# MSSubClass      -0.084284
# EnclosedPorch   -0.128578
# KitchenAbvGr    -0.135907
# Name: SalePrice, dtype: float64

# %% [markdown]
# ### Checking null-values in tran dataset:

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
# Id               1460 non-null int64
# MSSubClass       1460 non-null int64
# MSZoning         1460 non-null object
# LotFrontage      1201 non-null float64
# LotArea          1460 non-null int64
# Street           1460 non-null object
# Alley            91 non-null object
# LotShape         1460 non-null object
# LandContour      1460 non-null object
# Utilities        1460 non-null object
# LotConfig        1460 non-null object
# LandSlope        1460 non-null object
# Neighborhood     1460 non-null object
# Condition1       1460 non-null object
# Condition2       1460 non-null object
# BldgType         1460 non-null object
# HouseStyle       1460 non-null object
# OverallQual      1460 non-null int64
# OverallCond      1460 non-null int64
# YearBuilt        1460 non-null int64
# YearRemodAdd     1460 non-null int64
# RoofStyle        1460 non-null object
# ...

# %% [markdown]
# ### There are missing values of variables in train dataset. In case of linear regression it is a problem, so it is necesseary to handle them (eg. impute).

# %% [markdown]
# ### Importing Numpy package:

# %%
import numpy as np

# %% [markdown]
# ### Examining categorical variables in dataset (count if number of not-null rows, unique counts the number of unique values. top is the most commonly occurring value, with the frequency of the top value shown by freq)

# %%
categoricals = train.select_dtypes(exclude=[np.number])
categoricals.describe()
# Out:
#        MSZoning Street Alley LotShape LandContour Utilities LotConfig  \
# count      1460   1460    91     1460        1460      1460      1460
# unique        5      2     2        4           4         2         5
# top          RL   Pave  Grvl      Reg         Lvl    AllPub    Inside
# freq       1151   1454    50      925        1311      1459      1052
#
#        LandSlope Neighborhood Condition1      ...      GarageType  \
# count       1460         1460       1460      ...            1379
# unique         3           25          9      ...               6
# top          Gtl        NAmes       Norm      ...          Attchd
# freq        1382          225       1260      ...             870
#
#        GarageFinish GarageQual GarageCond PavedDrive PoolQC  Fence  \
# count          1379       1379       1379       1460      7    281
# unique            3          5          5          3      3      4
# top             Unf         TA         TA          Y     Gd  MnPrv
# ...

# %%
numericals = train.select_dtypes(include=[np.number])
numericals
# Out:
#         Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0        1          60         65.0     8450            7            5
# 1        2          20         80.0     9600            6            8
# 2        3          60         68.0    11250            7            5
# 3        4          70         60.0     9550            7            5
# 4        5          60         84.0    14260            8            5
# 5        6          50         85.0    14115            5            5
# 6        7          20         75.0    10084            8            5
# 7        8          60          NaN    10382            7            6
# 8        9          50         51.0     6120            7            5
# 9       10         190         50.0     7420            5            6
# 10      11          20         70.0    11200            5            5
# 11      12          60         85.0    11924            9            5
# ...

# %%
for iter in range (0,37):
        train[:,iter].fillna(train[:,iter].mean(), inplace=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-6594e6c31ab1> in <module>()
#       1 for iter in range (0,37):
# ----> 2         train[:,iter].fillna(train[:,iter].mean(), inplace=True)
#
# ~\AppData\Local\conda\conda\envs\mgr\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2683             return self._getitem_multilevel(key)
#    2684         else:
# -> 2685             return self._getitem_column(key)
#    2686
#    2687     def _getitem_column(self, key):
#
# ~\AppData\Local\conda\conda\envs\mgr\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2690         # get column
#    2691         if self.columns.is_unique:
# -> 2692             return self._get_item_cache(key)
#    2693
#    2694         # duplicate columns & possible reduce dimensionality
#
# ...

# %% [markdown]
# ### Preparing target variable y and set of exploratory variables X for model:

# %%
y = np.log(train.SalePrice)
X = train.drop(['SalePrice', 'Id'], axis=1)

# %% [markdown]
# ### Preparing train and test dataset for independent model performance assessment:

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=123, test_size=0.2)

# %% [markdown]
# ### Creating an instance of linear regression model:

# %%
from sklearn import linear_model
lr = linear_model.LinearRegression()

# %% [markdown]
# ### Fitting the linear regression model on train data:

# %%
model = lr.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-973ba42df3ee> in <module>()
# ----> 1 model = lr.fit(X_train, y_train)
#
# ~\AppData\Local\conda\conda\envs\mgr\lib\site-packages\sklearn\linear_model\base.py in fit(self, X, y, sample_weight)
#     480         n_jobs_ = self.n_jobs
#     481         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 482                          y_numeric=True, multi_output=True)
#     483
#     484         if sample_weight is not None and np.atleast_1d(sample_weight).ndim > 1:
#
# ~\AppData\Local\conda\conda\envs\mgr\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
# ...

# %% [markdown]
# ### Evaluating the performance of model with r-squared (as default measure for lr model scoring):

# %%
print ("R^2 is: \n", model.score(X_test, y_test))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-de603f8213eb> in <module>()
# ----> 1 print ("R^2 is: \n", model.score(X_test, y_test))
#
# NameError: name 'model' is not defined

# %% [markdown]
# ### RMSE of built model:

# %%
from sklearn.metrics import mean_squared_error
print ('RMSE is: \n', mean_squared_error(y_test, model.predict(X_test)))

# %% [markdown]
# ### Scatter plot of actual and estimated values of target variable (SalesPrice):

# %%
actual_values = y_test
plt.scatter(predictions, actual_values, alpha=.75,
            color='b') #alpha helps to show overlapping data
plt.xlabel('Predicted Price')
plt.ylabel('Actual Price')
plt.title('Linear Regression Model')
